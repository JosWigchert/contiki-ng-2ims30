# %%
import pandas as pd
import numpy as np

# %%
#config

border_router = "fe80::212:4b00:1665:3283"

pcap_df = pd.read_csv("pcap.csv")
pcap_df = pcap_df.drop(["No.", "Protocol", "Length"], axis=1)

rank_border_router = int(pcap_df[pcap_df["Source"] == border_router]["Rank"].unique()[0])
if rank_border_router == 128: # differntiate for mode used
    distance_from_parent = 128
else:
    distance_from_parent = 256

# %%
nodes = pcap_df[(pcap_df["Source"] != border_router)]
nodes = nodes[(nodes["Rank"] < rank_border_router+distance_from_parent)]
nodes
# Out:
#             Time                    Source               Destination   Rank  \
# 173   839.244594  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  133.0
# 175   887.291981  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 184   963.014938  fe80::212:4b00:1665:2a04                  ff02::1a  132.0
# 185   968.550142  fe80::212:4b00:1665:2a04  fe80::212:4b00:1192:fd83  132.0
# 192  1051.563760  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  132.0
# 194  1116.230658  fe80::212:4b00:1665:2a04  fe80::212:4b00:1665:3283  132.0
# 196  1154.677372  fe80::212:4b00:1665:2a04  fe80::212:4b00:1192:fd83  130.0
# 198  1187.224887  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 199  1187.225299  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 200  1187.253267  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 201  1187.253729  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 202  1187.283499  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 203  1187.328450  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 204  1187.328864  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 205  1187.358610  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  137.0
# 206  1219.114950  fe80::212:4b00:1665:2a04  fe80::212:4b00:1665:3283  129.0
# 215  1265.876563  fe80::212:4b00:1665:2a04  fe80::212:4b00:1192:fd83  130.0
# 217  1293.972579  fe80::212:4b00:1665:2a04                  ff02::1a  129.0
# 220  1327.213941  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 221  1327.258498  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 222  1327.288512  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 223  1327.288911  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 224  1327.307562  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 225  1327.307963  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 226  1327.348747  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 227  1327.349154  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 228  1369.125554  fe80::212:4b00:1665:2a04  fe80::212:4b00:1192:fd83  129.0
# 238  1453.068711  fe80::212:4b00:1665:2a04  fe80::212:4b00:1665:3283  137.0
# 242  1504.655836  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 243  1504.671164  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 244  1504.671571  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 245  1504.700434  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 246  1504.725717  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 247  1504.726398  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 248  1504.755656  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
# 249  1504.800739  fe80::212:4b00:1665:2a04   fe80::212:4b00:1193:101  129.0
#
#      Sequence Number                                    Info
# 173               93  RPL Control (DODAG Information Object)
# 175               94  RPL Control (DODAG Information Object)
# 184               96  RPL Control (DODAG Information Object)
# 185               97  RPL Control (DODAG Information Object)
# 192               98  RPL Control (DODAG Information Object)
# 194               99  RPL Control (DODAG Information Object)
# 196              100  RPL Control (DODAG Information Object)
# 198              101  RPL Control (DODAG Information Object)
# 199              101  RPL Control (DODAG Information Object)
# 200              101  RPL Control (DODAG Information Object)
# 201              101  RPL Control (DODAG Information Object)
# 202              101  RPL Control (DODAG Information Object)
# 203              101  RPL Control (DODAG Information Object)
# 204              101  RPL Control (DODAG Information Object)
# 205              101  RPL Control (DODAG Information Object)
# 206              102  RPL Control (DODAG Information Object)
# 215              103  RPL Control (DODAG Information Object)
# 217              104  RPL Control (DODAG Information Object)
# 220              105  RPL Control (DODAG Information Object)
# 221              105  RPL Control (DODAG Information Object)
# 222              105  RPL Control (DODAG Information Object)
# 223              105  RPL Control (DODAG Information Object)
# 224              105  RPL Control (DODAG Information Object)
# 225              105  RPL Control (DODAG Information Object)
# 226              105  RPL Control (DODAG Information Object)
# 227              105  RPL Control (DODAG Information Object)
# 228              106  RPL Control (DODAG Information Object)
# 238              107  RPL Control (DODAG Information Object)
# 242              109  RPL Control (DODAG Information Object)
# 243              109  RPL Control (DODAG Information Object)
# 244              109  RPL Control (DODAG Information Object)
# 245              109  RPL Control (DODAG Information Object)
# 246              109  RPL Control (DODAG Information Object)
# 247              109  RPL Control (DODAG Information Object)
# 248              109  RPL Control (DODAG Information Object)
# 249              109  RPL Control (DODAG Information Object)

# %%
possible_parents = []

for i in range(len(pcap_df)):
    destinations_found = []
    for j in range(i, 0, -1):
        if pcap_df.iloc[i]["Source"] == pcap_df.iloc[j]["Source"]:
            destinations_found.append(pcap_df.iloc[j]["Destination"])
        if len(destinations_found) > 5:
            
            break
    possible_parents.append(destinations_found)

# %%
probable_parents = [None] * len(possible_parents)

for i in range(len(possible_parents)):
    try: 
        probable_parents[i] = max(set(possible_parents[i]), key=possible_parents.count)
    except:
        probable_parents[i] = None

# %%
pcap_df.insert(5,"probable_parent" , probable_parents)

# %%
probable_parents_rank = []

for i in range(len(pcap_df)):
    parent_rank = None
    for j in range(i, 0, -1):
        if pcap_df.iloc[i]["probable_parent"] == pcap_df.iloc[j]["Source"] and not np.isnan(pcap_df.iloc[j]["Rank"]):
            parent_rank = pcap_df.iloc[j]["Rank"]
            break
    probable_parents_rank.append(parent_rank)

# %%
pcap_df.insert(6,"probable_parent_rank" , probable_parents_rank)

# %%
result = pcap_df.replace("fe80::212:4b00:1192:fd83", "Node 1")
result = result.replace("fe80::212:4b00:1665:3283", "Border Router")
result = result.replace("fe80::212:4b00:1665:2a04", "Malicious Node")
result = result.replace("fe80::212:4b00:1193:101", "Node 2")
pd.set_option("display.max_rows", 400, "display.max_columns", None)
len(result[(result["Rank"] - result["probable_parent_rank"]).abs() < distance_from_parent])
#(result["Rank"] - result["probable_parent_rank"]).abs()
# Out:
# 38

# %%
for i in pcap_df["Source"].unique():
    if i != border_router:
        rank_difference = []
        temp_df = pcap_df[pcap_df["Source"] == i]
        
        for i in temp.index:
            print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 6
#       3 rank_difference = []
#       4 temp_df = pcap_df[pcap_df["Source"] == i]
# ----> 6 for i in temp.index:
#       7     print(i)
#
# NameError: name 'temp' is not defined
